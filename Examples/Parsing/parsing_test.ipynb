# %% [markdown]
# # Language in ACT-R: Parsing a Sentence
#
# This notebook will show a simple demo of how ACT-R reads a sentence.
#
# The main model code is contained in the file `reading.lisp`.

# %%
import os.path
import random
import actr

# %% [markdown]
# Now, let's create some functions to parse a sentence in a word

# %%
SENTENCES = ["the boy kicks the ball",
             "the pundit ponders the circumstance",
             "the expert examines the situation"]

WORD_SPACE = 25

CHAR_SPACE = 10

def word_length(word):
    """Calculates a word length in monotype font"""
    return len(word) * CHAR_SPACE

def add_sentence_to_exp_window(win, sentence, x, y):
    """Adds a sentence one word at a time"""
    words = sentence.split()
    start = x
    for word in sentence.split():
        actr.add_text_to_exp_window(win, word, start, y)
        start += word_length(word)
        start += WORD_SPACE

def setup_reading():
    """Sets up the reading model and the reading interface"""
    actr.load_act_r_model(os.path.realpath("parsing.lisp"))
    win = actr.open_exp_window("Sentence", width = 600, height = 400)
    actr.install_device(win)
    add_sentence_to_exp_window(win, random.choice(SENTENCES), x = 100, y = 200)

# %%
setup_reading()
actr.run_n_events(2)
actr.print_visicon()
# Out:
# #|Warning: Productions request a value for the VERB slot in a request to the IMAGINAL buffer, but that slot is not used in other productions. |#
#      0.000   ------                 Stopped because event limit reached
# Name              Att  Loc             TEXT  KIND  COLOR  WIDTH  VALUE        HEIGHT  SIZE
# ----------------  ---  --------------  ----  ----  -----  -----  -----------  ------  ---------
# VISUAL-LOCATION0  NEW  (411 506 1080)  T     TEXT  BLACK  21     "the"        10      0.59
# VISUAL-LOCATION1  NEW  (477 506 1080)  T     TEXT  BLACK  42     "expert"     10      1.18
# VISUAL-LOCATION2  NEW  (569 506 1080)  T     TEXT  BLACK  56     "examines"   10      1.5799999
# VISUAL-LOCATION3  NEW  (656 506 1080)  T     TEXT  BLACK  21     "the"        10      0.59
# VISUAL-LOCATION4  NEW  (733 506 1080)  T     TEXT  BLACK  63     "situation"  10      1.77

# %%
actr.run(3)
# Out:
#      0.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0 NIL
#      0.000   VISION                 visicon-update
#      0.000   PROCEDURAL             CONFLICT-RESOLUTION
#      0.050   PROCEDURAL             PRODUCTION-FIRED START
#      0.050   PROCEDURAL             CLEAR-BUFFER GOAL
#      0.050   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      0.050   VISION                 Find-location
#      0.050   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0
#      0.050   GOAL                   SET-BUFFER-CHUNK GOAL CHUNK0
#      0.050   PROCEDURAL             CONFLICT-RESOLUTION
#      0.100   VISION                 Move-attention VISUAL-LOCATION0-1
#      0.100   PROCEDURAL             CONFLICT-RESOLUTION
#      0.185   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#      0.185   VISION                 SET-BUFFER-CHUNK VISUAL TEXT0
#      0.185   PROCEDURAL             CONFLICT-RESOLUTION
#      0.235   PROCEDURAL             PRODUCTION-FIRED FIND-MEANING
#      0.235   PROCEDURAL             CLEAR-BUFFER VISUAL
#      0.235   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      0.235   DECLARATIVE            start-retrieval
#      0.235   DECLARATIVE            RETRIEVED-CHUNK THE
#      0.235   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL THE
#      0.235   PROCEDURAL             CONFLICT-RESOLUTION
#      0.285   PROCEDURAL             PRODUCTION-FIRED START-NP
#      0.285   GOAL                   MOD-BUFFER-CHUNK GOAL
#      0.285   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      0.285   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      0.285   PROCEDURAL             CONFLICT-RESOLUTION
#      0.335   PROCEDURAL             PRODUCTION-FIRED NEXT-WORD
#      0.335   GOAL                   MOD-BUFFER-CHUNK GOAL
#      0.335   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      0.335   VISION                 Find-location
#      0.335   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION1
#      0.335   PROCEDURAL             CONFLICT-RESOLUTION
#      0.385   VISION                 Move-attention VISUAL-LOCATION1-0
#      0.385   PROCEDURAL             CONFLICT-RESOLUTION
#      0.470   VISION                 Encoding-complete VISUAL-LOCATION1-0 NIL
#      0.470   VISION                 SET-BUFFER-CHUNK VISUAL TEXT1
#      0.470   PROCEDURAL             CONFLICT-RESOLUTION
#      0.485   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK1
#      0.520   PROCEDURAL             PRODUCTION-FIRED FIND-MEANING
#      0.520   PROCEDURAL             CLEAR-BUFFER VISUAL
#      0.520   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      0.520   DECLARATIVE            start-retrieval
#      0.520   DECLARATIVE            RETRIEVED-CHUNK EXPERT
#      0.520   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL EXPERT
#      0.520   PROCEDURAL             CONFLICT-RESOLUTION
#      0.570   PROCEDURAL             PRODUCTION-FIRED ADD-NOUN-TO-NP
#      0.570   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      0.570   PROCEDURAL             CONFLICT-RESOLUTION
#      0.770   IMAGINAL               MOD-BUFFER-CHUNK IMAGINAL
#      0.770   PROCEDURAL             CONFLICT-RESOLUTION
#      0.820   PROCEDURAL             PRODUCTION-FIRED ATTACH-NP
#      0.820   GOAL                   MOD-BUFFER-CHUNK GOAL
#      0.820   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      0.820   PROCEDURAL             CONFLICT-RESOLUTION
#      0.870   PROCEDURAL             PRODUCTION-FIRED NEXT-WORD
#      0.870   GOAL                   MOD-BUFFER-CHUNK GOAL
#      0.870   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      0.870   VISION                 Find-location
#      0.870   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION2
#      0.870   PROCEDURAL             CONFLICT-RESOLUTION
#      0.920   VISION                 Move-attention VISUAL-LOCATION2-0
#      0.920   PROCEDURAL             CONFLICT-RESOLUTION
#      1.005   VISION                 Encoding-complete VISUAL-LOCATION2-0 NIL
#      1.005   VISION                 SET-BUFFER-CHUNK VISUAL TEXT2
#      1.005   PROCEDURAL             CONFLICT-RESOLUTION
#      1.055   PROCEDURAL             PRODUCTION-FIRED FIND-MEANING
#      1.055   PROCEDURAL             CLEAR-BUFFER VISUAL
#      1.055   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      1.055   DECLARATIVE            start-retrieval
#      1.055   DECLARATIVE            RETRIEVED-CHUNK EXAMINES
#      1.055   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL EXAMINES
#      1.055   PROCEDURAL             CONFLICT-RESOLUTION
#      1.105   PROCEDURAL             PRODUCTION-FIRED START-VP
#      1.105   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      1.105   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      1.105   PROCEDURAL             CONFLICT-RESOLUTION
#      1.305   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK2
#      1.305   PROCEDURAL             CONFLICT-RESOLUTION
#      1.355   PROCEDURAL             PRODUCTION-FIRED SAVE-SENTENCE
#      1.355   PROCEDURAL             CLEAR-BUFFER GOAL
#      1.355   PROCEDURAL             CONFLICT-RESOLUTION
#      1.405   PROCEDURAL             PRODUCTION-FIRED SWITCH-CONTEXT-1
#      1.405   PROCEDURAL             CONFLICT-RESOLUTION
#      1.605   IMAGINAL               MOD-BUFFER-CHUNK IMAGINAL
#      1.605   PROCEDURAL             CONFLICT-RESOLUTION
#      1.655   PROCEDURAL             PRODUCTION-FIRED SWITCH-CONTEXT-2
#      1.655   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      1.655   PROCEDURAL             CONFLICT-RESOLUTION
#      1.705   PROCEDURAL             PRODUCTION-FIRED NEXT-WORD
#      1.705   GOAL                   MOD-BUFFER-CHUNK GOAL
#      1.705   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      1.705   VISION                 Find-location
#      1.705   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION3
#      1.705   PROCEDURAL             CONFLICT-RESOLUTION
#      1.755   VISION                 Move-attention VISUAL-LOCATION3-0
#      1.755   PROCEDURAL             CONFLICT-RESOLUTION
#      1.840   VISION                 Encoding-complete VISUAL-LOCATION3-0 NIL
#      1.840   VISION                 SET-BUFFER-CHUNK VISUAL TEXT3
#      1.840   PROCEDURAL             CONFLICT-RESOLUTION
#      1.890   PROCEDURAL             PRODUCTION-FIRED FIND-MEANING
#      1.890   PROCEDURAL             CLEAR-BUFFER VISUAL
#      1.890   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      1.890   DECLARATIVE            start-retrieval
#      1.890   DECLARATIVE            RETRIEVED-CHUNK THE
#      1.890   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL THE
#      1.890   PROCEDURAL             CONFLICT-RESOLUTION
#      1.940   PROCEDURAL             PRODUCTION-FIRED START-NP
#      1.940   GOAL                   MOD-BUFFER-CHUNK GOAL
#      1.940   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      1.940   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      1.940   PROCEDURAL             CONFLICT-RESOLUTION
#      1.990   PROCEDURAL             PRODUCTION-FIRED NEXT-WORD
#      1.990   GOAL                   MOD-BUFFER-CHUNK GOAL
#      1.990   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      1.990   VISION                 Find-location
#      1.990   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION4
#      1.990   PROCEDURAL             CONFLICT-RESOLUTION
#      2.040   VISION                 Move-attention VISUAL-LOCATION4-0
#      2.040   PROCEDURAL             CONFLICT-RESOLUTION
#      2.125   VISION                 Encoding-complete VISUAL-LOCATION4-0 NIL
#      2.125   VISION                 SET-BUFFER-CHUNK VISUAL TEXT4
#      2.125   PROCEDURAL             CONFLICT-RESOLUTION
#      2.140   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK3
#      2.175   PROCEDURAL             PRODUCTION-FIRED FIND-MEANING
#      2.175   PROCEDURAL             CLEAR-BUFFER VISUAL
#      2.175   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      2.175   DECLARATIVE            start-retrieval
#      2.175   DECLARATIVE            RETRIEVED-CHUNK SITUATION
#      2.175   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL SITUATION
#      2.175   PROCEDURAL             CONFLICT-RESOLUTION
#      2.225   PROCEDURAL             PRODUCTION-FIRED ADD-NOUN-TO-NP
#      2.225   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      2.225   PROCEDURAL             CONFLICT-RESOLUTION
#      2.425   IMAGINAL               MOD-BUFFER-CHUNK IMAGINAL
#      2.425   PROCEDURAL             CONFLICT-RESOLUTION
#      2.475   PROCEDURAL             PRODUCTION-FIRED ATTACH-NP
#      2.475   GOAL                   MOD-BUFFER-CHUNK GOAL
#      2.475   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      2.475   PROCEDURAL             CONFLICT-RESOLUTION
#      2.525   PROCEDURAL             PRODUCTION-FIRED NEXT-WORD
#      2.525   GOAL                   MOD-BUFFER-CHUNK GOAL
#      2.525   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      2.525   VISION                 Find-location
#      2.525   VISION                 FIND-LOC-FAILURE
#      2.525   PROCEDURAL             CONFLICT-RESOLUTION
#      2.575   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-SENTENCE
#      2.575   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      2.575   DECLARATIVE            start-retrieval
#      2.575   DECLARATIVE            RETRIEVED-CHUNK CHUNK0-0
#      2.575   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK0-0
#      2.575   PROCEDURAL             CONFLICT-RESOLUTION
#      2.625   PROCEDURAL             PRODUCTION-FIRED BACK-ON-SENTENCE
#      2.625   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      2.625   PROCEDURAL             CONFLICT-RESOLUTION
#      2.825   IMAGINAL               MOD-BUFFER-CHUNK IMAGINAL
#      2.825   PROCEDURAL             CONFLICT-RESOLUTION
#      2.875   PROCEDURAL             PRODUCTION-FIRED CLOSE-SENTENCE
#      2.875   GOAL                   MOD-BUFFER-CHUNK GOAL
#      2.875   PROCEDURAL             CLEAR-BUFFER GOAL
#      2.875   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      2.875   ------                 BREAK-EVENT Stopped by !stop!
# [2.875, 338, True]
